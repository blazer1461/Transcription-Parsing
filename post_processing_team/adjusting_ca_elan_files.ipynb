# %% [markdown]
# IN THIS SECTION, WE ARE REMOVING ALL THE GAPS AND EXTRA SPACES FROM A .CA FILE

# %%
file = open("2018-11-18-session_2.cha")

# %%
lines = file.readlines()

# %%
# this code removes a lot of (not all of) the special CA charactersv 
with open("2018-11-18-session_2-done.cha", "w") as f:
    for line in lines:
        if line[0:2] != "\t(":
            # if the line does not start with a tab, then replace all the following with nothing 
            line = line.replace("⌉  ", "⌉ ")
            line = line.replace("⌋  ", "⌋ ")
            line = line.replace("  ⌋  ", " ⌋")
            line = line.replace("s  ","s ")
            line = line.replace(")  ", ") ")
            line = line.replace("	 ","	") 
            line = line.replace("  &", " &")
            line = line.replace(":::",":")
            line = line.replace(":::",":")
            line = line.replace("::::",":")
            line = line.replace("[⌈]","")
            line = line.replace("> <", "")
            line = line.replace("[>]", "")
            f.write(line)

# %%
IN THIS SECTION, WE REMOVE ALL LINES THAT START WITH GAP BECAUSE I MADE A MISTAKE

# %%
# you can ignore this code
file = open("newfile.ca")
lines = file.readlines()
with open("newfile2.ca", "w") as f:
    for line in lines:
        if line[0:2] != "*G":
            f.write(line)

# %% [markdown]
# IN THIS SECTION, WE ARE TAKING ELAN --> CHAT FILES AND ADJUSTING THE GAPS
#
# The ELAN output has all gaps in a ton of decimals. .cha files should only have gaps that round to at least 300ms, and it should be formatted like (0.3)

# %%
file = open("2017-10-30-session-3-gaps.cha")

# %%
lines = file.readlines() 
import re 
import textwrap
    
with open("2017-10-30-session-3-gaps-done.cha", "w") as f:
    for line in lines:
        line = line.replace("  ", " ")
        line = line.replace("*REP:", "%rep:")
        # this bit is to just replace things that aren't the right format 
        
        if line[0] == "@": 
            # this is to skip the header information 
            f.write(line)
        elif line[0:5] == "*GAP:": 
            # all "gap" lines stat with "*GAP"
            gaplength = float(line[5:10])
            # this gets the gap 
            
            if gaplength <= .08:
                line = ("\t" + "LATCH" + "\n")
                f.write(line)
                # if there's less than an 80ms gap between turns, then place a latch symbol 
                
            else:
                gaplength = round(gaplength, 1)
                if gaplength >= .3:
                    line = ("\t" + "(" + str(gaplength) + ")" + line[11:len(line)])
                    f.write(line)
        else:
            line = line.replace("  ", " ")
            f.write(line)

# %% [markdown]
# # Goal: to extract FTOs.
# The plan:
#
# (1) Process turn one. Store the speaker, start time and end time.
# (2) Process turn two. Store the speaker, start time and end time.
# (3) Check to see whether turn two speaker = turn one speaker. If true, skip the rest. If they are different speakers, continue.
# (4) Calculate the difference in start times. If they are very similar (<80ms), then:
# -- if this is the first and second utterances, just skip.
# -- otherwise, compare the speaker of the second turn to the speaker of the turn before turn one. If they are different speakers, do (start time of turn two) - (end time of turn 0).
# (5) otherwise, calcualte: (start time of turn two) - (end time of turn one)
# (6) in a file, save: speaker of previous turn | end time of previous turn one | speaker of turn two | FTO between turn two and previous turn

# %%
# create a class so you can make utterance objects and eventually manipulate them

class Turn: 
    # initializing function 
    def __init__(self, speaker, words, start_time, end_time): 
        self.speaker = speaker
        self.words = words 
        self.start_time = start_time
        self.end_time = end_time
        self.duration = end_time - start_time

# %% [markdown]
# ### find-turn:
#
# this function creates a Turn object from a list of lines and a integer representing the turn to start off on.
#
# It returns the Turn object and the line number in the file. The line number is important because the function skips lines that do not start with *

# %%
# this is the function that finds the next non-gap, non-@ turn 
def find_turn(n, linelist): 
    # find something that is not a "*"
    while(linelist[n][0] != "*"): 
        n = n+1
    line = linelist[n]
    speaker = line.split(":")[0]
    times = line.split("\x15")[1]
    start_time = int(times.split("_")[0])
    end_time = int(times.split("_")[1])
    words = line.split(":")[1]
    words = words.split("\x15")[0]
    return Turn(speaker, words, start_time, end_time), n

# %% [markdown]
# ### calculate_fto:
#
# This function takes two Turns and calculates the FTO between them. You MUST input the first turn first and the second turn second.
#
# If the speakers of the two turns are the same, this function returns -99,999 miliseconds (-99 seconds). If the speakers of the two turns are different but start at very similar times, this function returns 99,999 (99 seconds).

# %%
def calculate_fto(second, first): 
    if abs(second.start_time - first.start_time) < 80: 
        return 99999
    # elif first.speaker == second.speaker: 
    #   return -99999
    else: 
        # print(second.start_time, first.end_time, second.start_time - first.end_time)
        FTO = second.start_time - first.end_time
        return FTO

# %%
def make_FTO_string(turn1, turn2, FTO, n): 
    return (str(n) + "," + turn2.speaker + "," + str(turn2.start_time) +"," + str(turn2.end_time) + "," + turn2.words + "," + str(FTO) + "," + turn1.words + "," + str(turn1.start_time) + "," + str(turn1.end_time) + "," + turn1.speaker + "\n")

# %%
file = open("2018-11-06-session-3.cha")
lines = file.readlines() 
n = 0 

# create three Turns
twobefore_turn, n = find_turn(n, lines)
onebefore_turn, n = find_turn(n+1, lines)
current, n = find_turn(n+1, lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-53da7f010d3b> in <module>
# ----> 1 file = open("2018-11-06-session-3.cha")
#       2 lines = file.readlines()
#       3 n = 0
#       4
#       5 # create three Turns
#
# FileNotFoundError: [Errno 2] No such file or directory: '2018-11-06-session-3.cha'

# %%
proportion = .3
chars_after = .3 * len(newtext)
index = len(newtext) - round(chars_after)

newtext = newtext[:index] + "⌈" + newtext[index:] + "⌉"
print(newtext)
# Out:
# this is a practi⌈⌈ce test⌉⌉

# %%
### THIS CELL WILL REPLACE OVERLAP MARKERS AND LATCHES. BUT!!! IT WILL REMOVE METADATA AND CODES. 
# MAKE SURE TO REPLACE THE METADATA AND CODES AFTER THIS, AS WELL 
# AS RUN THE FIX_BULLETS AND INDENT COMMANDS IN CLAN
import re
file = open("2017-10-30-session-3.cha")
lines = file.readlines() 
n = 0 

# create three Turns
twobefore_turn, n = find_turn(n, lines)
onebefore_turn, n = find_turn(n+1, lines)
current, n = find_turn(n+1, lines)

with open("2017-10-30-session-3-new.cha", "w") as f:
    # we only want to process twobefore at the beginning
    twobefore_turn.words = twobefore_turn.words.replace('⌉', '')
    twobefore_turn.words = twobefore_turn.words.replace('&=laughs', '')
    twobefore_turn.words = onebefore_turn.words.replace('&=Laughs', '')
    twobefore_turn.words = twobefore_turn.words.replace('⌋', '')
    twobefore_turn.words = twobefore_turn.words.replace('⌈', '')
    twobefore_turn.words = twobefore_turn.words.replace('⌊', '')
    twobefore_turn.words = twobefore_turn.words.replace(':', '')
    twobefore_turn.words = twobefore_turn.words.replace('≈', '')
    twobefore_turn.words = twobefore_turn.words.replace('  ', ' ').strip()
    
    while lines[n+1][0] != "@" and (lines[n][0] == "*"): 
        FTO = calculate_fto(onebefore_turn, twobefore_turn)
    
        # strip the turns and remove all current overlap markers    
        onebefore_turn.words = onebefore_turn.words.replace('⌉ ', '')
        onebefore_turn.words = onebefore_turn.words.replace('&=laughs', '')
        onebefore_turn.words = onebefore_turn.words.replace('&=Laughs', '')
        onebefore_turn.words = onebefore_turn.words.replace('⌋', '')
        onebefore_turn.words = onebefore_turn.words.replace('⌈', '')
        onebefore_turn.words = onebefore_turn.words.replace('⌊', '')
        onebefore_turn.words = onebefore_turn.words.replace(':', '')
        onebefore_turn.words = onebefore_turn.words.replace('≈', '')
        onebefore_turn.words = onebefore_turn.words.replace('  ',' ').strip()

        # add an overlap marker if the FTO is negative
        if (FTO < 0):
            print("line n: ", n, " has a negative FTO")
            # if FTO is negative, then the previous turn should have an overlap till the end
            # the current turn should have an overlap marker at the beginning of the turn
            # we need to calculate where the other two overlap markers belong 
            before_proportion = abs(FTO) / twobefore_turn.duration
            after_proportion = abs(FTO) / onebefore_turn.duration
            
            # before_char figures out how far into the previous turn to start the overlap 
            before_char = round(before_proportion * len(twobefore_turn.words))
            if (before_char == 0): 
                before_char = 1
                
            # after_char figures out how far into the current turn to end the overlap 
            after_char = round(after_proportion * len(onebefore_turn.words))
            if (after_char == 0): 
                after_char = 1

            # before index in the index we'll use to place the starting overlap in the first turn
            before_index = len(twobefore_turn.words) - before_char     
            
            # after_index is the index we'll use to place the ending overlap in the second turn 
            after_index = after_char
            
            # does the first turn end after the second turn? 
            if (twobefore_turn.end_time > onebefore_turn.end_time): 
                # if so, we need to figure out where to put the ending overlap 
                prop = (twobefore_turn.end_time - onebefore_turn.end_time) / twobefore_turn.duration
                yikes_index = len(twobefore_turn.words) - round(prop * len(twobefore_turn.words))
            else: 
                yikes_index = len(twobefore_turn.words)
            
            before_text = twobefore_turn.words[:before_index] + "⌈" + twobefore_turn.words[before_index:yikes_index] + "⌉" + twobefore_turn.words[yikes_index:]
            twobefore_turn.words = before_text 
            
            after_text = "⌊" + onebefore_turn.words[:after_index] + "⌋" + onebefore_turn.words[after_index:]
            #print(onebefore_turn.words)
            onebefore_turn.words = after_text 

        if (FTO < 80 and FTO > 0): 
            twobefore_turn.words = twobefore_turn.words + "≈"
            onebefore_turn.words = "≈" + onebefore_turn.words 
        
        f.write(twobefore_turn.speaker + ":\t" + twobefore_turn.words + "    " + "•" + str(twobefore_turn.start_time) + "_" + str(twobefore_turn.end_time) + "•\n")
        
        twobefore_turn = onebefore_turn
        onebefore_turn = current
        current, n = find_turn(n+1, lines)
    
    f.write(twobefore_turn.speaker + ":\t" + twobefore_turn.words + "    " + "•" + str(twobefore_turn.start_time) + "_" + str(twobefore_turn.end_time) + "•\n")
    f.write(onebefore_turn.speaker + ":\t" + onebefore_turn.words + "    " + "•" + str(onebefore_turn.start_time) + "_" + str(onebefore_turn.end_time) + "•\n")
# Out:
# line n:  11  has a negative FTO
# line n:  21  has a negative FTO
# line n:  25  has a negative FTO
# line n:  28  has a negative FTO
# line n:  29  has a negative FTO
# line n:  32  has a negative FTO
# line n:  34  has a negative FTO
# line n:  35  has a negative FTO
# line n:  38  has a negative FTO
# line n:  39  has a negative FTO
# line n:  42  has a negative FTO
# line n:  44  has a negative FTO
# line n:  51  has a negative FTO
# line n:  52  has a negative FTO
# line n:  53  has a negative FTO
# line n:  59  has a negative FTO
# line n:  60  has a negative FTO
# line n:  61  has a negative FTO
# line n:  62  has a negative FTO
# line n:  66  has a negative FTO
# line n:  67  has a negative FTO
# line n:  68  has a negative FTO
# line n:  70  has a negative FTO
# line n:  74  has a negative FTO
# line n:  75  has a negative FTO
# line n:  76  has a negative FTO
# line n:  77  has a negative FTO
# line n:  82  has a negative FTO
# line n:  83  has a negative FTO
# line n:  88  has a negative FTO
# line n:  92  has a negative FTO
# line n:  99  has a negative FTO
# line n:  100  has a negative FTO
# line n:  110  has a negative FTO
# line n:  112  has a negative FTO
# line n:  114  has a negative FTO
# line n:  116  has a negative FTO
# line n:  117  has a negative FTO
# line n:  120  has a negative FTO
# line n:  122  has a negative FTO
# line n:  124  has a negative FTO
# line n:  126  has a negative FTO
# line n:  128  has a negative FTO
# line n:  134  has a negative FTO
# line n:  135  has a negative FTO
# line n:  138  has a negative FTO
# line n:  139  has a negative FTO
# line n:  141  has a negative FTO
# line n:  142  has a negative FTO
# line n:  145  has a negative FTO
# line n:  149  has a negative FTO
# line n:  152  has a negative FTO
# line n:  153  has a negative FTO
# line n:  154  has a negative FTO
# line n:  155  has a negative FTO
# line n:  161  has a negative FTO
# line n:  162  has a negative FTO
# line n:  163  has a negative FTO
# line n:  165  has a negative FTO
# line n:  167  has a negative FTO
# line n:  169  has a negative FTO
# line n:  172  has a negative FTO
# line n:  176  has a negative FTO
# line n:  178  has a negative FTO
# line n:  180  has a negative FTO
# line n:  182  has a negative FTO
# line n:  183  has a negative FTO
# line n:  186  has a negative FTO
# line n:  190  has a negative FTO
# line n:  191  has a negative FTO
# line n:  193  has a negative FTO
# line n:  194  has a negative FTO
# line n:  199  has a negative FTO
# line n:  201  has a negative FTO
# line n:  207  has a negative FTO
# line n:  208  has a negative FTO
# line n:  213  has a negative FTO
# line n:  214  has a negative FTO
# line n:  219  has a negative FTO
# line n:  223  has a negative FTO
# line n:  225  has a negative FTO
# line n:  230  has a negative FTO
# line n:  231  has a negative FTO
# line n:  233  has a negative FTO
# line n:  234  has a negative FTO
# line n:  235  has a negative FTO
# line n:  237  has a negative FTO
# line n:  239  has a negative FTO
# line n:  246  has a negative FTO
# line n:  250  has a negative FTO
# line n:  251  has a negative FTO
# line n:  253  has a negative FTO
# line n:  256  has a negative FTO
# line n:  260  has a negative FTO
# line n:  264  has a negative FTO
# line n:  270  has a negative FTO
# line n:  272  has a negative FTO
# line n:  273  has a negative FTO
# line n:  275  has a negative FTO
# line n:  277  has a negative FTO
# line n:  279  has a negative FTO
# line n:  281  has a negative FTO
# line n:  282  has a negative FTO
# line n:  284  has a negative FTO
# line n:  286  has a negative FTO
# line n:  287  has a negative FTO
# line n:  288  has a negative FTO
# line n:  289  has a negative FTO
# line n:  290  has a negative FTO
# line n:  291  has a negative FTO
# line n:  296  has a negative FTO
# line n:  297  has a negative FTO
# line n:  298  has a negative FTO
# line n:  301  has a negative FTO
# line n:  302  has a negative FTO
# line n:  303  has a negative FTO
# line n:  307  has a negative FTO
# line n:  310  has a negative FTO
# line n:  313  has a negative FTO
# line n:  314  has a negative FTO
# line n:  315  has a negative FTO
# line n:  318  has a negative FTO
# line n:  319  has a negative FTO
# line n:  323  has a negative FTO
# line n:  324  has a negative FTO
# line n:  325  has a negative FTO
# line n:  328  has a negative FTO
# line n:  330  has a negative FTO
# line n:  331  has a negative FTO
# line n:  334  has a negative FTO
# line n:  336  has a negative FTO
# line n:  338  has a negative FTO
# line n:  340  has a negative FTO
# line n:  341  has a negative FTO
# line n:  343  has a negative FTO
# line n:  347  has a negative FTO
# line n:  348  has a negative FTO
# line n:  352  has a negative FTO
# line n:  353  has a negative FTO
# line n:  357  has a negative FTO
# line n:  359  has a negative FTO
# line n:  360  has a negative FTO
# line n:  362  has a negative FTO
# line n:  365  has a negative FTO
# line n:  373  has a negative FTO
# line n:  375  has a negative FTO
# line n:  379  has a negative FTO
# line n:  381  has a negative FTO
# line n:  382  has a negative FTO
# line n:  384  has a negative FTO
# line n:  386  has a negative FTO
# line n:  388  has a negative FTO
# line n:  390  has a negative FTO
# line n:  393  has a negative FTO
# line n:  396  has a negative FTO
# line n:  398  has a negative FTO
# line n:  400  has a negative FTO
# line n:  402  has a negative FTO
# line n:  405  has a negative FTO
# line n:  406  has a negative FTO
# line n:  410  has a negative FTO
# line n:  417  has a negative FTO
# line n:  419  has a negative FTO
# line n:  420  has a negative FTO
# line n:  421  has a negative FTO
# line n:  422  has a negative FTO
# line n:  423  has a negative FTO
# line n:  424  has a negative FTO
# line n:  426  has a negative FTO
# line n:  428  has a negative FTO
# line n:  430  has a negative FTO
# line n:  432  has a negative FTO
# line n:  434  has a negative FTO
# line n:  439  has a negative FTO
# line n:  441  has a negative FTO
# line n:  443  has a negative FTO
# line n:  448  has a negative FTO
# line n:  450  has a negative FTO
# line n:  454  has a negative FTO
# line n:  456  has a negative FTO
# line n:  459  has a negative FTO
# line n:  462  has a negative FTO
# line n:  466  has a negative FTO
# line n:  467  has a negative FTO
# line n:  471  has a negative FTO
# line n:  473  has a negative FTO
# line n:  475  has a negative FTO
# line n:  479  has a negative FTO
# line n:  481  has a negative FTO
# line n:  482  has a negative FTO
# line n:  483  has a negative FTO
# line n:  485  has a negative FTO
# line n:  491  has a negative FTO
# line n:  492  has a negative FTO
# line n:  494  has a negative FTO
# line n:  496  has a negative FTO
# line n:  499  has a negative FTO
# line n:  500  has a negative FTO
# line n:  501  has a negative FTO
# line n:  502  has a negative FTO
# line n:  503  has a negative FTO
# line n:  504  has a negative FTO
# line n:  506  has a negative FTO
# line n:  507  has a negative FTO
# line n:  509  has a negative FTO
# line n:  510  has a negative FTO
# line n:  513  has a negative FTO
# line n:  514  has a negative FTO
# line n:  515  has a negative FTO
# line n:  516  has a negative FTO
# line n:  517  has a negative FTO
# line n:  519  has a negative FTO
# line n:  521  has a negative FTO
# line n:  522  has a negative FTO
# line n:  523  has a negative FTO
# line n:  524  has a negative FTO
# line n:  528  has a negative FTO
# line n:  530  has a negative FTO
# line n:  533  has a negative FTO
# line n:  535  has a negative FTO
# line n:  538  has a negative FTO
# line n:  541  has a negative FTO
# line n:  544  has a negative FTO
# line n:  545  has a negative FTO
# line n:  548  has a negative FTO
# line n:  552  has a negative FTO
# line n:  553  has a negative FTO
# line n:  554  has a negative FTO
# line n:  555  has a negative FTO
# line n:  557  has a negative FTO
# line n:  559  has a negative FTO
# line n:  562  has a negative FTO
# line n:  563  has a negative FTO
# line n:  565  has a negative FTO
# line n:  567  has a negative FTO
# line n:  571  has a negative FTO
# line n:  574  has a negative FTO
# line n:  575  has a negative FTO
# line n:  578  has a negative FTO
# line n:  580  has a negative FTO
# line n:  581  has a negative FTO
# line n:  588  has a negative FTO
# line n:  594  has a negative FTO
# line n:  596  has a negative FTO
# line n:  597  has a negative FTO
# line n:  600  has a negative FTO
# line n:  601  has a negative FTO
# line n:  602  has a negative FTO
# line n:  606  has a negative FTO
# line n:  612  has a negative FTO
# line n:  615  has a negative FTO
# line n:  617  has a negative FTO
# line n:  619  has a negative FTO
# line n:  620  has a negative FTO
# line n:  621  has a negative FTO
# line n:  623  has a negative FTO
# line n:  627  has a negative FTO
# line n:  628  has a negative FTO
# line n:  630  has a negative FTO
# line n:  634  has a negative FTO
# line n:  635  has a negative FTO
# line n:  638  has a negative FTO
# line n:  641  has a negative FTO
# line n:  643  has a negative FTO
# line n:  650  has a negative FTO
# line n:  652  has a negative FTO
# line n:  654  has a negative FTO
# line n:  660  has a negative FTO
# line n:  662  has a negative FTO
# line n:  666  has a negative FTO
# line n:  671  has a negative FTO
# line n:  673  has a negative FTO
# line n:  679  has a negative FTO
# line n:  684  has a negative FTO
# line n:  689  has a negative FTO
# line n:  691  has a negative FTO
# line n:  693  has a negative FTO
# line n:  694  has a negative FTO
# line n:  695  has a negative FTO
# line n:  696  has a negative FTO
# line n:  697  has a negative FTO
# line n:  700  has a negative FTO
# line n:  702  has a negative FTO
# line n:  705  has a negative FTO
# line n:  710  has a negative FTO
# line n:  713  has a negative FTO
# line n:  716  has a negative FTO
# line n:  718  has a negative FTO
# line n:  719  has a negative FTO
# line n:  721  has a negative FTO
# line n:  726  has a negative FTO
# line n:  727  has a negative FTO
# line n:  728  has a negative FTO
# line n:  729  has a negative FTO
# line n:  732  has a negative FTO
# line n:  734  has a negative FTO
# line n:  741  has a negative FTO
# line n:  742  has a negative FTO
# line n:  745  has a negative FTO
# line n:  749  has a negative FTO
# line n:  750  has a negative FTO
# line n:  753  has a negative FTO
# line n:  761  has a negative FTO
# line n:  764  has a negative FTO
# line n:  766  has a negative FTO
# line n:  767  has a negative FTO
# line n:  768  has a negative FTO
# line n:  769  has a negative FTO
# line n:  771  has a negative FTO
# line n:  772  has a negative FTO
# line n:  773  has a negative FTO
# line n:  774  has a negative FTO
# line n:  779  has a negative FTO
# line n:  780  has a negative FTO
# line n:  784  has a negative FTO
# line n:  786  has a negative FTO
# line n:  787  has a negative FTO
# line n:  789  has a negative FTO
# line n:  791  has a negative FTO
# line n:  793  has a negative FTO
# line n:  797  has a negative FTO
# line n:  799  has a negative FTO
# line n:  800  has a negative FTO
# line n:  801  has a negative FTO
# line n:  804  has a negative FTO
# line n:  806  has a negative FTO
# line n:  807  has a negative FTO
# line n:  808  has a negative FTO
# line n:  815  has a negative FTO
# line n:  819  has a negative FTO
# line n:  820  has a negative FTO
# line n:  821  has a negative FTO
# line n:  827  has a negative FTO
# line n:  835  has a negative FTO
# line n:  837  has a negative FTO
# line n:  838  has a negative FTO
# line n:  843  has a negative FTO
# line n:  844  has a negative FTO
# line n:  846  has a negative FTO
# line n:  847  has a negative FTO
# line n:  849  has a negative FTO
# line n:  850  has a negative FTO
# line n:  851  has a negative FTO
# line n:  855  has a negative FTO
# line n:  861  has a negative FTO
# line n:  863  has a negative FTO
# line n:  865  has a negative FTO
# line n:  867  has a negative FTO
# line n:  868  has a negative FTO
# line n:  869  has a negative FTO
# line n:  870  has a negative FTO
# line n:  876  has a negative FTO
# line n:  880  has a negative FTO
# line n:  881  has a negative FTO
# line n:  883  has a negative FTO
# line n:  886  has a negative FTO
# line n:  888  has a negative FTO
# line n:  889  has a negative FTO
# line n:  895  has a negative FTO
# line n:  896  has a negative FTO
# line n:  898  has a negative FTO
# line n:  900  has a negative FTO
# line n:  902  has a negative FTO
# line n:  906  has a negative FTO
# line n:  909  has a negative FTO
# line n:  912  has a negative FTO
# line n:  914  has a negative FTO
# line n:  916  has a negative FTO
# line n:  917  has a negative FTO
# line n:  919  has a negative FTO
# line n:  929  has a negative FTO
# line n:  934  has a negative FTO
# line n:  935  has a negative FTO
# line n:  938  has a negative FTO
# line n:  940  has a negative FTO
# line n:  942  has a negative FTO
# line n:  944  has a negative FTO
# line n:  946  has a negative FTO
# line n:  947  has a negative FTO
# line n:  949  has a negative FTO
# line n:  952  has a negative FTO
# line n:  957  has a negative FTO
# line n:  959  has a negative FTO
# line n:  963  has a negative FTO
# line n:  965  has a negative FTO
# line n:  967  has a negative FTO
# line n:  970  has a negative FTO
# line n:  972  has a negative FTO
# line n:  974  has a negative FTO
# line n:  980  has a negative FTO
# line n:  982  has a negative FTO
# line n:  984  has a negative FTO
# line n:  986  has a negative FTO
# line n:  989  has a negative FTO
# line n:  994  has a negative FTO
# line n:  997  has a negative FTO
# line n:  998  has a negative FTO
# line n:  1002  has a negative FTO
# line n:  1004  has a negative FTO
# line n:  1006  has a negative FTO
# line n:  1010  has a negative FTO
# line n:  1014  has a negative FTO
# line n:  1017  has a negative FTO
# line n:  1019  has a negative FTO
# line n:  1020  has a negative FTO
# line n:  1022  has a negative FTO
# line n:  1029  has a negative FTO
# line n:  1035  has a negative FTO
# line n:  1038  has a negative FTO
# line n:  1041  has a negative FTO
# line n:  1042  has a negative FTO
# line n:  1044  has a negative FTO
# line n:  1045  has a negative FTO
# line n:  1047  has a negative FTO
# line n:  1052  has a negative FTO
# line n:  1057  has a negative FTO
# line n:  1059  has a negative FTO
# line n:  1060  has a negative FTO
# line n:  1063  has a negative FTO
# line n:  1069  has a negative FTO
# line n:  1071  has a negative FTO
# line n:  1072  has a negative FTO
# line n:  1075  has a negative FTO
# line n:  1078  has a negative FTO
# line n:  1084  has a negative FTO
# line n:  1085  has a negative FTO
# line n:  1088  has a negative FTO
# line n:  1089  has a negative FTO
# line n:  1090  has a negative FTO
# line n:  1092  has a negative FTO
# line n:  1093  has a negative FTO
# line n:  1098  has a negative FTO
# line n:  1099  has a negative FTO
# line n:  1100  has a negative FTO
# line n:  1104  has a negative FTO
# line n:  1105  has a negative FTO
# line n:  1107  has a negative FTO
# line n:  1108  has a negative FTO
# line n:  1109  has a negative FTO
# line n:  1114  has a negative FTO
# line n:  1115  has a negative FTO
# line n:  1119  has a negative FTO
# line n:  1125  has a negative FTO
# line n:  1127  has a negative FTO
# line n:  1128  has a negative FTO
# line n:  1130  has a negative FTO

# %%
file = open("2018-11-06-session-1.cha")
lines = file.readlines() 

n = 0 
# create three Turns
twobefore_turn, n = find_turn(n, lines)
onebefore_turn, n = find_turn(n+1, lines)
current, n = find_turn(n+1, lines)

# create the .txt file and make the headers 
f = open("demofile2.txt", "a")
f.write("line," + "previousturn_speaker," + "previousturn_starttime," + "previousturn_endtime," + "previous_turn," + "FTO," + "next_turn," + "nextturn_starttime," + "nextturn_endtime," + "nextturn_speaker" + "\n")

# calculate the first FTO and add to the file 
first_FTO = calculate_fto(onebefore_turn, twobefore_turn)
if abs(first_FTO) < 90000: 
    f.write(make_FTO_string(onebefore_turn, twobefore_turn, first_FTO, n))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-292-c26ba9d96782> in <module>
# ----> 1 file = open("2018-11-06-session-1.cha")
#       2 lines = file.readlines()
#       3
#       4 n = 0
#       5 # create three Turns
#
# FileNotFoundError: [Errno 2] No such file or directory: '2018-11-06-session-1.cha'

# %%
# while the rest of the file is going on: 
while lines[n+1][0] != "@" and lines[n][0] == "*": 
    print(str(n))
    # first, calculate FTO between current and previous 
    if twobefore_turn.end_time > onebefore_turn.end_time: 
        onebefore_turn = twobefore_turn
    
    FTO = calculate_fto(current, onebefore_turn)

    # if the result is fine, add the FTO and incrementore
    if abs(FTO) < 90000: 
        print("abs FTO < 90000")
        f.write(make_FTO_string(current, onebefore_turn, FTO, n))
        print("moving on")
        twobefore_turn = onebefore_turn
        onebefore_turn = current
        current, n = find_turn(n+1, lines)
    
    # otherwise, if it's positive 99999 (they began speaking at almost exactly the same time)
    elif FTO > 90000: 
        print("FTO is greater than 90000")
        
    # then check the FTO between current and twobefore 
        FTO = calculate_fto(current, twobefore_turn)
    
    # if that result is fine, add the FTO 
        if abs(FTO) < 90000: 
            print("abs FTO 2 is < 90000")
            f.write(make_FTO_string(current, twobefore_turn, FTO, n))
            print("moving on")
            twobefore_turn = onebefore_turn
            onebefore_turn = current
            current, n = find_turn(n+1, lines)
    
        else: 
            print("abs FTO is < 90000")
            print("moving on")
            twobefore_turn = onebefore_turn
            onebefore_turn = current
            current, n = find_turn(n+1, lines)
            
    else:
        print("moving on")
        twobefore_turn = onebefore_turn
        onebefore_turn = current
        current, n = find_turn(n+1, lines)
            
# close the file
f.close()
# Out:
# 13
# 61881 54076 7805
# abs FTO < 90000
# moving on
# 14
# 65602 65646 -44
# abs FTO < 90000
# moving on
# 16
# 67065 65986 1079
# abs FTO < 90000
# moving on
# 17
# 67893 68769 -876
# abs FTO < 90000
# moving on
# 19
# 73181 69030 4151
# abs FTO < 90000
# moving on
# 21
# 82695 80767 1928
# abs FTO < 90000
# moving on
# 23
# 89995 89258 737
# abs FTO < 90000
# moving on
# 24
# 94488 94600 -112
# abs FTO < 90000
# moving on
# 25
# 95046 95250 -204
# abs FTO < 90000
# moving on
# 27
# 102962 101895 1067
# abs FTO < 90000
# moving on
# 29
# 103820 103216 604
# abs FTO < 90000
# moving on
# 30
# 103918 104779 -861
# abs FTO < 90000
# moving on
# 31
# 105439 105360 79
# abs FTO < 90000
# moving on
# 33
# 105541 107000 -1459
# abs FTO < 90000
# moving on
# 34
# 108567 108720 -153
# abs FTO < 90000
# moving on
# 35
# 111111 111334 -223
# abs FTO < 90000
# moving on
# 36
# 111651 111786 -135
# abs FTO < 90000
# moving on
# 37
# 114297 114595 -298
# abs FTO < 90000
# moving on
# 38
# 115023 114818 205
# abs FTO < 90000
# moving on
# 39
# 119590 119939 -349
# abs FTO < 90000
# moving on
# 40
# 120369 120172 197
# abs FTO < 90000
# moving on
# 41
# 124488 125683 -1195
# abs FTO < 90000
# moving on
# 42
# 125353 125683 -330
# abs FTO < 90000
# moving on
# 43
# 126279 126532 -253
# abs FTO < 90000
# moving on
# 44
# 126676 126834 -158
# abs FTO < 90000
# moving on
# 46
# 130760 129760 1000
# abs FTO < 90000
# moving on
# 47
# 134976 134846 130
# abs FTO < 90000
# moving on
# 48
# 135639 135727 -88
# abs FTO < 90000
# moving on
# 49
# 137458 137997 -539
# abs FTO < 90000
# moving on
# 51
# 139139 138337 802
# abs FTO < 90000
# moving on
# 52
# 141732 141516 216
# abs FTO < 90000
# moving on
# 53
# FTO is greater than 90000
# 141795 141516 279
# abs FTO 2 is < 90000
# moving on
# 54
# 143204 143260 -56
# abs FTO < 90000
# moving on
# 55
# 144623 145310 -687
# abs FTO < 90000
# moving on
# 57
# 146283 145310 973
# abs FTO < 90000
# moving on
# 59
# 148497 148220 277
# abs FTO < 90000
# moving on
# 60
# 150669 150462 207
# abs FTO < 90000
# moving on
# 61
# 153139 153046 93
# abs FTO < 90000
# moving on
# 62
# 153416 154248 -832
# abs FTO < 90000
# moving on
# 64
# 159300 157681 1619
# abs FTO < 90000
# moving on
# 65
# 160467 160700 -233
# abs FTO < 90000
# moving on
# 67
# 161553 161193 360
# abs FTO < 90000
# moving on
# 68
# 161967 162190 -223
# abs FTO < 90000
# moving on
# 69
# 165297 165844 -547
# abs FTO < 90000
# moving on
# 70
# 168132 168246 -114
# abs FTO < 90000
# moving on
# 72
# 169579 168300 1279
# abs FTO < 90000
# moving on
# 74
# 172044 171627 417
# abs FTO < 90000
# moving on
# 75
# 175237 176416 -1179
# abs FTO < 90000
# moving on
# 77
# 178013 176416 1597
# abs FTO < 90000
# moving on
# 78
# 180441 180530 -89
# abs FTO < 90000
# moving on
# 79
# 181051 181000 51
# abs FTO < 90000
# moving on
# 81
# 181390 181634 -244
# abs FTO < 90000
# moving on
# 82
# 185025 185269 -244
# abs FTO < 90000
# moving on
# 83
# 185881 185793 88
# abs FTO < 90000
# moving on
# 85
# 189023 187753 1270
# abs FTO < 90000
# moving on
# 86
# 191372 191390 -18
# abs FTO < 90000
# moving on
# 87
# 191774 191886 -112
# abs FTO < 90000
# moving on
# 88
# 196627 196855 -228
# abs FTO < 90000
# moving on
# 90
# 198518 197788 730
# abs FTO < 90000
# moving on
# 92
# 201234 199386 1848
# abs FTO < 90000
# moving on
# 94
# 203297 202513 784
# abs FTO < 90000
# moving on
# 96
# 204304 203981 323
# abs FTO < 90000
# moving on
# 98
# 205427 204767 660
# abs FTO < 90000
# moving on
# 100
# 209023 205766 3257
# abs FTO < 90000
# moving on
# 102
# 219489 219411 78
# abs FTO < 90000
# moving on
# 103
# 219790 220150 -360
# abs FTO < 90000
# moving on
# 104
# FTO is greater than 90000
# 219791 220150 -359
# abs FTO 2 is < 90000
# moving on
# 105
# 223948 223834 114
# abs FTO < 90000
# moving on
# 106
# FTO is greater than 90000
# 224009 223834 175
# abs FTO 2 is < 90000
# moving on
# 107
# 224997 224806 191
# abs FTO < 90000
# moving on
# 109
# 227095 227510 -415
# abs FTO < 90000
# moving on
# 111
# 228139 228411 -272
# abs FTO < 90000
# moving on
# 112
# 230030 229997 33
# abs FTO < 90000
# moving on
# 113
# 230374 230493 -119
# abs FTO < 90000
# moving on
# 114
# 231432 231830 -398
# abs FTO < 90000
# moving on
# 116
# 232165 231830 335
# abs FTO < 90000
# moving on
# 118
# 233665 233383 282
# abs FTO < 90000
# moving on
# 119
# 234140 234146 -6
# abs FTO < 90000
# moving on
# 120
# 234839 234855 -16
# abs FTO < 90000
# moving on
# 121
# 235295 235193 102
# abs FTO < 90000
# moving on
# 122
# 237453 237365 88
# abs FTO < 90000
# moving on
# 123
# 238100 237995 105
# abs FTO < 90000
# moving on
# 125
# 242158 240890 1268
# abs FTO < 90000
# moving on
# 126
# FTO is greater than 90000
# 242160 240890 1270
# abs FTO 2 is < 90000
# moving on
# 127
# 244023 243818 205
# abs FTO < 90000
# moving on
# 128
# 245074 245039 35
# abs FTO < 90000
# moving on
# 129
# 245455 245655 -200
# abs FTO < 90000
# moving on
# 131
# 248148 247665 483
# abs FTO < 90000
# moving on
# 133
# 250369 248597 1772
# abs FTO < 90000
# moving on
# 134
# 252383 252495 -112
# abs FTO < 90000
# moving on
# 136
# 261041 259432 1609
# abs FTO < 90000
# moving on
# 138
# 265523 264316 1207
# abs FTO < 90000
# moving on
# 140
# 271521 271123 398
# abs FTO < 90000
# moving on
# 141
# 271709 272221 -512
# abs FTO < 90000
# moving on
# 142
# 272790 276316 -3526
# abs FTO < 90000
# moving on
# 143
# 276372 276316 56
# abs FTO < 90000
# moving on
# 144
# 281440 281469 -29
# abs FTO < 90000
# moving on
# 146
# 282334 282005 329
# abs FTO < 90000
# moving on
# 147
# 294179 294627 -448
# abs FTO < 90000
# moving on
# 149
# 295079 294627 452
# abs FTO < 90000
# moving on
# 150
# 299511 299360 151
# abs FTO < 90000
# moving on
# 151
# 309997 310383 -386
# abs FTO < 90000
# moving on
# 152
# 310711 310476 235
# abs FTO < 90000
# moving on
# 153
# 315897 316304 -407
# abs FTO < 90000
# moving on
# 155
# 316790 316304 486
# abs FTO < 90000
# moving on
# 156
# 321330 321541 -211
# abs FTO < 90000
# moving on
# 157
# 321997 321760 237
# abs FTO < 90000
# moving on
# 158
# 326423 326353 70
# abs FTO < 90000
# moving on
# 159
# 328879 328720 159
# abs FTO < 90000
# moving on
# 161
# 330676 329509 1167
# abs FTO < 90000
# moving on
# 162
# 331872 332313 -441
# abs FTO < 90000
# moving on
# 164
# 333639 332495 1144
# abs FTO < 90000
# moving on
# 165
# 338400 338841 -441
# abs FTO < 90000
# moving on
# 166
# 338969 339353 -384
# abs FTO < 90000
# moving on
# 168
# 339955 339353 602
# abs FTO < 90000
# moving on
# 169
# 340213 340581 -368
# abs FTO < 90000
# moving on
# 171
# 344846 344072 774
# abs FTO < 90000
# moving on
# 173
# 348337 347267 1070
# abs FTO < 90000
# moving on
# 174
# 355025 355200 -175
# abs FTO < 90000
# moving on
# 175
# 355820 356040 -220
# abs FTO < 90000
# moving on
# 177
# 356725 356344 381
# abs FTO < 90000
# moving on
# 179
# 362730 359546 3184
# abs FTO < 90000
# moving on
# 181
# 372427 370762 1665
# abs FTO < 90000
# moving on
# 182
# 375181 376607 -1426
# abs FTO < 90000
# moving on
# 184
# 377044 376762 282
# abs FTO < 90000
# moving on
# 185
# 382407 382223 184
# abs FTO < 90000
# moving on
# 187
# 385948 384874 1074
# abs FTO < 90000
# moving on
# 188
# 387239 388337 -1098
# abs FTO < 90000
# moving on
# 190
# 388920 388337 583
# abs FTO < 90000
# moving on
# 192
# 394769 394507 262
# abs FTO < 90000
# moving on
# 193
# 394979 395360 -381
# abs FTO < 90000
# moving on
# 194
# 396600 396472 128
# abs FTO < 90000
# moving on
# 195
# 411841 411660 181
# abs FTO < 90000
# moving on
# 196
# 413258 413300 -42
# abs FTO < 90000
# moving on
# 198
# 414037 413751 286
# abs FTO < 90000
# moving on
# 199
# 415593 415907 -314
# abs FTO < 90000
# moving on
# 201
# 417397 415907 1490
# abs FTO < 90000
# moving on
# 203
# 420902 418630 2272
# abs FTO < 90000
# moving on
# 205
# 427632 426946 686
# abs FTO < 90000
# moving on
# 207
# 432118 431827 291
# abs FTO < 90000
# moving on
# 209
# 438574 437107 1467
# abs FTO < 90000
# moving on
# 210
# 443183 446772 -3589
# abs FTO < 90000
# moving on
# 212
# 447546 446772 774
# abs FTO < 90000
# moving on
# 214
# 449583 448030 1553
# abs FTO < 90000
# moving on
# 215
# 450220 450123 97
# abs FTO < 90000
# moving on
# 216
# 460009 460111 -102
# abs FTO < 90000
# moving on
# 217
# 460651 460611 40
# abs FTO < 90000
# moving on
# 218
# 465011 464990 21
# abs FTO < 90000
# moving on
# 220
# 466125 465602 523
# abs FTO < 90000
# moving on
# 221
# FTO is greater than 90000
# 466190 465602 588
# abs FTO 2 is < 90000
# moving on
# 222
# 466872 466904 -32
# abs FTO < 90000
# moving on
# 223
# 472818 472732 86
# abs FTO < 90000
# moving on
# 224
# 479195 481314 -2119
# abs FTO < 90000
# moving on
# 225
# 481100 481314 -214
# abs FTO < 90000
# moving on
# 227
# 482311 481730 581
# abs FTO < 90000
# moving on
# 229
# 483655 483104 551
# abs FTO < 90000
# moving on
# 231
# 496858 495062 1796
# abs FTO < 90000
# moving on
# 233
# 502700 500260 2440
# abs FTO < 90000
# moving on
# 235
# 505267 504010 1257
# abs FTO < 90000
# moving on
# 236
# 508004 508010 -6
# abs FTO < 90000
# moving on
# 237
# 511988 511830 158
# abs FTO < 90000
# moving on
# 239
# 513627 512820 807
# abs FTO < 90000
# moving on
# 240
# 515130 515751 -621
# abs FTO < 90000
# moving on
# 241
# 521295 521695 -400
# abs FTO < 90000
# moving on
# 242
# 523990 524788 -798
# abs FTO < 90000
# moving on
# 244
# 526453 525195 1258
# abs FTO < 90000
# moving on
# 245
# 529758 531127 -1369
# abs FTO < 90000
# moving on
# 247
# 533414 531127 2287
# abs FTO < 90000
# moving on
# 249
# 539902 539602 300
# abs FTO < 90000
# moving on
# 250
# 540153 540328 -175
# abs FTO < 90000
# moving on
# 251
# 541037 541062 -25
# abs FTO < 90000
# moving on
# 252
# 543248 543500 -252
# abs FTO < 90000
# moving on
# 253
# 544200 543988 212
# abs FTO < 90000
# moving on
# 255
# 545095 544588 507
# abs FTO < 90000
# moving on
# 257
# 551379 550788 591
# abs FTO < 90000
# moving on
# 258
# 551816 552293 -477
# abs FTO < 90000
# moving on
# 260
# 553134 552307 827
# abs FTO < 90000
# moving on
# 262
# 555162 554095 1067
# abs FTO < 90000
# moving on
# 263
# 557900 558469 -569
# abs FTO < 90000
# moving on
# 265
# 558948 558511 437
# abs FTO < 90000
# moving on
# 266
# 560630 560880 -250
# abs FTO < 90000
# moving on
# 267
# 562370 562390 -20
# abs FTO < 90000
# moving on
# 268
# 571234 571120 114
# abs FTO < 90000
# moving on
# 269
# 572534 572690 -156
# abs FTO < 90000
# moving on
# 271
# 574111 573044 1067
# abs FTO < 90000
# moving on
# 273
# 577802 576679 1123
# abs FTO < 90000
# moving on
# 275
# 582686 581651 1035
# abs FTO < 90000
# moving on
# 276
# 586286 587325 -1039
# abs FTO < 90000
# moving on
# 277
# 587300 587325 -25
# abs FTO < 90000
# moving on
# 278
# 589381 589723 -342
# abs FTO < 90000
# moving on
# 280
# 590723 589834 889
# abs FTO < 90000
# moving on
# 281
# 592130 592097 33
# abs FTO < 90000
# moving on
# 283
# 594662 592746 1916
# abs FTO < 90000
# moving on
# 284
# 596869 598658 -1789
# abs FTO < 90000
# moving on
# 286
# 599581 598658 923
# abs FTO < 90000
# moving on
# 287
# 605700 606381 -681
# abs FTO < 90000
# moving on
# 289
# 606865 606381 484
# abs FTO < 90000
# moving on
# 290
# 611186 611686 -500
# abs FTO < 90000
# moving on
# 292
# 612586 611804 782
# abs FTO < 90000
# moving on
# 293
# 614539 614718 -179
# abs FTO < 90000
# moving on
# 295
# 616497 615037 1460
# abs FTO < 90000
# moving on
# 297
# 618767 617044 1723
# abs FTO < 90000
# moving on
# 299
# 624397 623941 456
# abs FTO < 90000
# moving on
# 301
# 625300 624990 310
# abs FTO < 90000
# moving on
# 302
# 630507 630493 14
# abs FTO < 90000
# moving on
# 303
# 630710 631195 -485
# abs FTO < 90000
# moving on
# 305
# 633762 633295 467
# abs FTO < 90000
# moving on
# 306
# FTO is greater than 90000
# 633802 633295 507
# abs FTO 2 is < 90000
# moving on
# 307
# 635165 635910 -745
# abs FTO < 90000
# moving on
# 308
# 636010 635910 100
# abs FTO < 90000
# moving on
# 309
# 637518 637465 53
# abs FTO < 90000
# moving on
# 311
# 639323 638297 1026
# abs FTO < 90000
# moving on
# 312
# 644318 645595 -1277
# abs FTO < 90000
# moving on
# 313
# 645788 645595 193
# abs FTO < 90000
# moving on
# 315
# 647372 646300 1072
# abs FTO < 90000
# moving on
# 317
# 651372 650227 1145
# abs FTO < 90000
# moving on
# 319
# 657493 656702 791
# abs FTO < 90000
# moving on
# 321
# 659767 659402 365
# abs FTO < 90000
# moving on
# 322
# 659914 660183 -269
# abs FTO < 90000
# moving on
# 323
# 661018 660972 46
# abs FTO < 90000
# moving on
# 324
# 661841 661790 51
# abs FTO < 90000
# moving on
# 326
# 662811 662141 670
# abs FTO < 90000
# moving on
# 327
# 663511 663455 56
# abs FTO < 90000
# moving on
# 329
# 665276 663879 1397
# abs FTO < 90000
# moving on
# 331
# 676039 675523 516
# abs FTO < 90000
# moving on
# 333
# 677637 677280 357
# abs FTO < 90000
# moving on
# 335
# 680751 680083 668
# abs FTO < 90000
# moving on
# 338
# 683237 681358 1879
# abs FTO < 90000
# moving on
# 340
# 686276 684693 1583
# abs FTO < 90000
# moving on
# 341
# 690000 690160 -160
# abs FTO < 90000
# moving on
# 343
# 697111 696097 1014
# abs FTO < 90000
# moving on
# 345
# 701795 701351 444
# abs FTO < 90000
# moving on
# 347
# 702393 702348 45
# abs FTO < 90000
# moving on
# 348
# 703253 703262 -9
# abs FTO < 90000
# moving on
# 349
# 703876 704309 -433
# abs FTO < 90000
# moving on
# 351
# 706976 706034 942
# abs FTO < 90000
# moving on
# 352
# 707372 708681 -1309
# abs FTO < 90000
# moving on
# 354
# 709532 708681 851
# abs FTO < 90000
# moving on
# 356
# 710895 709953 942
# abs FTO < 90000
# moving on
# 357
# 713451 714160 -709
# abs FTO < 90000
# moving on
# 358
# 721583 721562 21
# abs FTO < 90000
# moving on
# 359
# 722125 722162 -37
# abs FTO < 90000
# moving on
# 360
# 727795 727695 100
# abs FTO < 90000
# moving on
# 362
# 729179 728339 840
# abs FTO < 90000
# moving on
# 363
# 734923 734800 123
# abs FTO < 90000
# moving on
# 364
# 735204 735328 -124
# abs FTO < 90000
# moving on
# 365
# 740423 740558 -135
# abs FTO < 90000
# moving on
# 366
# 742858 742950 -92
# abs FTO < 90000
# moving on
# 369
# 745230 744118 1112
# abs FTO < 90000
# moving on
# 371
# 748604 746776 1828
# abs FTO < 90000
# moving on
# 372
# 751288 751283 5
# abs FTO < 90000
# moving on
# 374
# 752558 751686 872
# abs FTO < 90000
# moving on
# 375
# 752639 753514 -875
# abs FTO < 90000
# moving on
# 377
# 754974 753604 1370
# abs FTO < 90000
# moving on
# 379
# 758100 757458 642
# abs FTO < 90000
# moving on
# 381
# 767600 766121 1479
# abs FTO < 90000
# moving on
# 382
# 770168 771630 -1462
# abs FTO < 90000
# moving on
# 383
# 771609 771630 -21
# abs FTO < 90000
# moving on
# 384
# 773176 773934 -758
# abs FTO < 90000
# moving on
# 385
# 776789 777004 -215
# abs FTO < 90000
# moving on
# 387
# 779786 779469 317
# abs FTO < 90000
# moving on
# 388
# 782509 782909 -400
# abs FTO < 90000
# moving on
# 389
# 783427 783644 -217
# abs FTO < 90000
# moving on
# 391
# 784597 783825 772
# abs FTO < 90000
# moving on
# 392
# 785730 785990 -260
# abs FTO < 90000
# moving on
# 393
# 786485 786550 -65
# abs FTO < 90000
# moving on
# 395
# 790285 788585 1700
# abs FTO < 90000
# moving on
# 397
# 796076 795771 305
# abs FTO < 90000
# moving on
# 399
# 798498 797940 558
# abs FTO < 90000
# moving on
# 400
# 801332 803730 -2398
# abs FTO < 90000
# moving on
# 402
# 804107 803730 377
# abs FTO < 90000
# moving on
# 404
# 806685 805448 1237
# abs FTO < 90000
# moving on
# 406
# 809926 808370 1556
# abs FTO < 90000
# moving on
# 407
# FTO is greater than 90000
# 809948 808370 1578
# abs FTO 2 is < 90000
# moving on
# 408
# 811044 811940 -896
# abs FTO < 90000
# moving on
# 409
# 817816 818676 -860
# abs FTO < 90000
# moving on
# 410
# 818929 818676 253
# abs FTO < 90000
# moving on
# 411
# 820413 821061 -648
# abs FTO < 90000
# moving on
# 413
# 821426 821061 365
# abs FTO < 90000
# moving on
# 414
# 821978 822481 -503
# abs FTO < 90000
# moving on
# 415
# 829546 831773 -2227
# abs FTO < 90000
# moving on
# 417
# 832381 831773 608
# abs FTO < 90000
# moving on
# 418
# 835857 835878 -21
# abs FTO < 90000
# moving on
# 420
# 837321 836492 829
# abs FTO < 90000
# moving on
# 421
# 840671 840928 -257
# abs FTO < 90000
# moving on
# 422
# 841758 842061 -303
# abs FTO < 90000
# moving on
# 424
# 844245 843951 294
# abs FTO < 90000
# moving on
# 425
# 844428 844608 -180
# abs FTO < 90000
# moving on
# 427
# 847048 845660 1388
# abs FTO < 90000
# moving on
# 428
# 853333 853191 142
# abs FTO < 90000
# moving on
# 429
# 853533 853811 -278
# abs FTO < 90000
# moving on
# 431
# 855893 855323 570
# abs FTO < 90000
# moving on
# 432
# 856298 856238 60
# abs FTO < 90000
# moving on
# 433
# 861531 861693 -162
# abs FTO < 90000
# moving on
# 434
# 863803 864033 -230
# abs FTO < 90000
# moving on
# 435
# 864276 864920 -644
# abs FTO < 90000
# moving on
# 436
# 869406 870090 -684
# abs FTO < 90000
# moving on
# 437
# 870125 870090 35
# abs FTO < 90000
# moving on
# 439
# 870883 870323 560
# abs FTO < 90000
# moving on
# 441
# 875008 874048 960
# abs FTO < 90000
# moving on
# 442
# 876293 876391 -98
# abs FTO < 90000
# moving on
# 443
# 878415 878596 -181
# abs FTO < 90000
# moving on
# 445
# 879013 878750 263
# abs FTO < 90000
# moving on
# 446
# 882156 882503 -347
# abs FTO < 90000
# moving on
# 448
# 883911 883566 345
# abs FTO < 90000
# moving on
# 449
# 891768 891526 242
# abs FTO < 90000
# moving on
# 450
# 891986 892113 -127
# abs FTO < 90000
# moving on
# 451
# 894951 894965 -14
# abs FTO < 90000
# moving on
# 452
# 895565 895321 244
# abs FTO < 90000
# moving on
# 454
# 898398 896600 1798
# abs FTO < 90000
# moving on
# 456
# 903193 902198 995
# abs FTO < 90000
# moving on
# 457
# 908475 908390 85
# abs FTO < 90000
# moving on
# 459
# 908830 908858 -28
# abs FTO < 90000
# moving on
# 460
# 915867 915748 119
# abs FTO < 90000
# moving on
# 461
# 916208 916277 -69
# abs FTO < 90000
# moving on
# 463
# 919123 917918 1205
# abs FTO < 90000
# moving on
# 464
# 928430 929655 -1225
# abs FTO < 90000
# moving on
# 466
# 929933 929655 278
# abs FTO < 90000
# moving on
# 467
# 934325 934640 -315
# abs FTO < 90000
# moving on
# 469
# 936298 934685 1613
# abs FTO < 90000
# moving on
# 471
# 940900 939780 1120
# abs FTO < 90000
# moving on
# 473
# 943888 942935 953
# abs FTO < 90000
# moving on
# 475
# 945480 945578 -98
# abs FTO < 90000
# moving on
# 476
# 959795 959835 -40
# abs FTO < 90000
# moving on
# 477
# 960398 960665 -267
# abs FTO < 90000
# moving on
# 478
# 961085 961050 35
# abs FTO < 90000
# moving on
# 480
# 962148 961768 380
# abs FTO < 90000
# moving on
# 482
# 963145 962538 607
# abs FTO < 90000
# moving on
# 483
# 965611 966335 -724
# abs FTO < 90000
# moving on
# 485
# 967363 966335 1028
# abs FTO < 90000
# moving on
# 487
# 971573 970595 978
# abs FTO < 90000
# moving on
# 488
# 972625 972573 52
# abs FTO < 90000
# moving on
# 490
# 973743 973243 500
# abs FTO < 90000
# moving on
# 491
# FTO is greater than 90000
# 973765 973243 522
# abs FTO 2 is < 90000
# moving on
# 493
# 976638 976253 385
# abs FTO < 90000
# moving on
# 495
# 980020 979145 875
# abs FTO < 90000
# moving on
# 497
# 983630 982310 1320
# abs FTO < 90000
# moving on
# 498
# 989775 989870 -95
# abs FTO < 90000
# moving on
# 500
# 992513 990543 1970
# abs FTO < 90000
# moving on
# 502
# 995098 994810 288
# abs FTO < 90000
# moving on
# 504
# 997918 997300 618
# abs FTO < 90000
# moving on
# 506
# 1000473 998740 1733
# abs FTO < 90000
# moving on
# 508
# 1002468 1002150 318
# abs FTO < 90000
# moving on
# 509
# 1005774 1007013 -1239
# abs FTO < 90000
# moving on
# 510
# 1007160 1007013 147
# abs FTO < 90000
# moving on
# 512
# 1008503 1007893 610
# abs FTO < 90000
# moving on
# 514
# 1010500 1009583 917
# abs FTO < 90000
# moving on
# 515
# 1012020 1012230 -210
# abs FTO < 90000
# moving on
# 516
# 1012483 1015968 -3485
# abs FTO < 90000
# moving on
# 518
# 1016318 1015968 350
# abs FTO < 90000
# moving on
# 520
# 1028050 1026810 1240
# abs FTO < 90000
# moving on
# 521
# 1031078 1031308 -230
# abs FTO < 90000
# moving on
# 523
# 1031990 1031581 409
# abs FTO < 90000
# moving on
# 525
# 1038013 1034983 3030
# abs FTO < 90000
# moving on
# 526
# 1043213 1045037 -1824
# abs FTO < 90000
# moving on
# 528
# 1045820 1045037 783
# abs FTO < 90000
# moving on
# 529
# 1051158 1053411 -2253
# abs FTO < 90000
# moving on
# 530
# 1053582 1053411 171
# abs FTO < 90000
# moving on
# 531
# 1057890 1058251 -361
# abs FTO < 90000
# moving on
# 532
# 1058485 1058488 -3
# abs FTO < 90000
# moving on
# 534
# 1061127 1059482 1645
# abs FTO < 90000
# moving on
# 536
# 1062967 1061606 1361
# abs FTO < 90000
# moving on
# 538
# 1067488 1066490 998
# abs FTO < 90000
# moving on
# 539
# 1067577 1068787 -1210
# abs FTO < 90000
# moving on
# 541
# 1069825 1068787 1038
# abs FTO < 90000
# moving on
# 542
# 1071713 1073056 -1343
# abs FTO < 90000
# moving on
# 544
# 1073624 1073210 414
# abs FTO < 90000
# moving on
# 546
# 1076140 1074958 1182
# abs FTO < 90000
# moving on
# 548
# 1077517 1077787 -270
# abs FTO < 90000
# moving on
# 549
# 1079044 1079142 -98
# abs FTO < 90000
# moving on
# 550
# 1079952 1079852 100
# abs FTO < 90000
# moving on
# 553
# 1083556 1080236 3320
# abs FTO < 90000
# moving on
# 555
# 1084787 1084887 -100
# abs FTO < 90000
# moving on
# 556
# 1085671 1085804 -133
# abs FTO < 90000
# moving on
# 558
# 1088458 1086062 2396
# abs FTO < 90000
# moving on
# 559
# 1090748 1090544 204
# abs FTO < 90000
# moving on
# 560
# 1090893 1091005 -112
# abs FTO < 90000
# moving on
# 561
# 1092615 1092852 -237
# abs FTO < 90000
# moving on
# 562
# 1095446 1095609 -163
# abs FTO < 90000
# moving on
# 564
# 1099186 1097899 1287
# abs FTO < 90000
# moving on
# 565
# 1105639 1105683 -44
# abs FTO < 90000
# moving on
# 566
# 1116479 1117642 -1163
# abs FTO < 90000
# moving on
# 567
# 1117757 1117642 115
# abs FTO < 90000
# moving on
# 569
# 1127736 1126532 1204
# abs FTO < 90000
# moving on
# 570
# 1128607 1128535 72
# abs FTO < 90000
# moving on
# 571
# 1128763 1128951 -188
# abs FTO < 90000
# moving on
# 572
# 1140234 1140245 -11
# abs FTO < 90000
# moving on
# 573
# 1140671 1140586 85
# abs FTO < 90000
# moving on
# 574
# 1146287 1146082 205
# abs FTO < 90000
# moving on
# 575
# 1146872 1147224 -352
# abs FTO < 90000
# moving on
# 578
# 1148097 1147224 873
# abs FTO < 90000
# moving on
# 579
# 1148855 1148733 122
# abs FTO < 90000
# moving on
# 581
# 1153677 1152074 1603
# abs FTO < 90000
# moving on
# 582
# 1154819 1154804 15
# abs FTO < 90000
# moving on
# 584
# 1158813 1157266 1547
# abs FTO < 90000
# moving on
# 586
# 1161579 1159446 2133
# abs FTO < 90000
# moving on
# 588
# 1167023 1165869 1154
# abs FTO < 90000
# moving on
# 589
# 1168556 1168480 76
# abs FTO < 90000
# moving on
# 590
# 1168905 1168908 -3
# abs FTO < 90000
# moving on
# 591
# 1173517 1173340 177
# abs FTO < 90000
# moving on
# 592
# 1178557 1178511 46
# abs FTO < 90000
# moving on
# 594
# 1179281 1178918 363
# abs FTO < 90000
# moving on
# 595
# 1182479 1183100 -621
# abs FTO < 90000
# moving on
# 597
# 1183940 1183100 840
# abs FTO < 90000
# moving on
# 599
# 1188099 1187710 389
# abs FTO < 90000
# moving on
# 600
# 1188269 1188437 -168
# abs FTO < 90000
# moving on
# 601
# 1190559 1190556 3
# abs FTO < 90000
# moving on
# 603
# 1193210 1190940 2270
# abs FTO < 90000
# moving on
# 605
# 1195964 1194745 1219
# abs FTO < 90000
# moving on
# 606
# 1199417 1199810 -393
# abs FTO < 90000
# moving on
# 608
# 1206476 1205801 675
# abs FTO < 90000
# moving on
# 609
# 1206973 1207266 -293
# abs FTO < 90000
# moving on
# 610
# 1221481 1221497 -16
# abs FTO < 90000
# moving on
# 611
# 1221769 1221933 -164
# abs FTO < 90000
# moving on
# 613
# 1224121 1223390 731
# abs FTO < 90000
# moving on
# 614
# FTO is greater than 90000
# 1224189 1223390 799
# abs FTO 2 is < 90000
# moving on
# 616
# 1225082 1225085 -3
# abs FTO < 90000
# moving on
# 618
# 1226346 1226003 343
# abs FTO < 90000
# moving on
# 619
# 1226624 1227071 -447
# abs FTO < 90000
# moving on
# 621
# 1231035 1230358 677
# abs FTO < 90000
# moving on
# 624
# 1234349 1234038 311
# abs FTO < 90000
# moving on
# 625
# 1235094 1235192 -98
# abs FTO < 90000
# moving on
# 627
# 1236686 1235905 781
# abs FTO < 90000
# moving on
# 628
# 1243420 1243239 181
# abs FTO < 90000
# moving on
# 629
# 1245393 1246850 -1457
# abs FTO < 90000
# moving on
# 630
# 1246852 1246850 2
# abs FTO < 90000
# moving on
# 632
# 1248766 1247304 1462
# abs FTO < 90000
# moving on
# 633
# 1276929 1276920 9
# abs FTO < 90000
# moving on
# 634
# 1277541 1279943 -2402
# abs FTO < 90000
# moving on
# 635
# 1279038 1279943 -905
# abs FTO < 90000
# moving on
# 637
# 1280485 1279943 542
# abs FTO < 90000
# moving on
# 639
# 1285603 1285148 455
# abs FTO < 90000
# moving on
# 641
# 1288106 1287003 1103
# abs FTO < 90000
# moving on
# 642
# 1291263 1291307 -44
# abs FTO < 90000
# moving on
# 643
# 1291920 1291724 196
# abs FTO < 90000
# moving on
# 644
# 1295152 1298810 -3658
# abs FTO < 90000
# moving on
# 646
# 1299088 1298810 278
# abs FTO < 90000
# moving on
# 648
# 1306023 1304260 1763
# abs FTO < 90000
# moving on
# 650
# 1308615 1307387 1228
# abs FTO < 90000
# moving on
# 651
# 1314130 1314192 -62
# abs FTO < 90000
# moving on
# 652
# 1314772 1315192 -420
# abs FTO < 90000
# moving on
# 653
# 1315710 1315893 -183
# abs FTO < 90000
# moving on
# 654
# 1319050 1318923 127
# abs FTO < 90000
# moving on
# 655
# 1319201 1319843 -642
# abs FTO < 90000
# moving on
# 656
# 1322550 1322514 36
# abs FTO < 90000
# moving on
# 657
# 1323275 1323248 27
# abs FTO < 90000
# moving on
# 659
# 1325843 1325530 313
# abs FTO < 90000
# moving on
# 660
# 1326588 1327417 -829
# abs FTO < 90000
# moving on
# 662
# 1329497 1329739 -242
# abs FTO < 90000
# moving on
# 663
# 1329955 1329790 165
# abs FTO < 90000
# moving on
# 664
# 1331565 1331722 -157
# abs FTO < 90000
# moving on
# 666
# 1335121 1333766 1355
# abs FTO < 90000
# moving on
# 667
# 1336837 1336955 -118
# abs FTO < 90000
# moving on
# 668
# 1340574 1341120 -546
# abs FTO < 90000
# moving on
# 670
# 1343050 1341639 1411
# abs FTO < 90000
# moving on
# 671
# 1349692 1349523 169
# abs FTO < 90000
# moving on
# 672
# FTO is greater than 90000
# 1349766 1349523 243
# abs FTO 2 is < 90000
# moving on
# 674
# 1354097 1353532 565
# abs FTO < 90000
# moving on
# 676
# 1356926 1355935 991
# abs FTO < 90000
# moving on
# 678
# 1359979 1358932 1047
# abs FTO < 90000
# moving on
# 679
# 1360319 1360994 -675
# abs FTO < 90000
# moving on
# 680
# 1361804 1361757 47
# abs FTO < 90000
# moving on
# 682
# 1364668 1364364 304
# abs FTO < 90000
# moving on
# 683
# 1368435 1368736 -301
# abs FTO < 90000
# moving on
# 684
# 1372328 1372390 -62
# abs FTO < 90000
# moving on
# 685
# 1372674 1372686 -12
# abs FTO < 90000
# moving on
# 687
# 1379186 1377393 1793
# abs FTO < 90000
# moving on
# 688
# 1380713 1381032 -319
# abs FTO < 90000
# moving on
# 689
# 1381707 1382213 -506
# abs FTO < 90000
# moving on
# 691
# 1383275 1382423 852
# abs FTO < 90000
# moving on
# 692
# 1385609 1385720 -111
# abs FTO < 90000
# moving on
# 694
# 1389319 1388165 1154
# abs FTO < 90000
# moving on
# 695
# 1397683 1397698 -15
# abs FTO < 90000
# moving on
# 697
# 1399053 1398278 775
# abs FTO < 90000
# moving on
# 699
# 1399840 1399242 598
# abs FTO < 90000
# moving on
# 701
# 1401724 1400822 902
# abs FTO < 90000
# moving on
# 703
# 1403103 1402754 349
# abs FTO < 90000
# moving on
# 704
# 1409014 1409009 5
# abs FTO < 90000
# moving on
# 706
# 1410553 1409550 1003
# abs FTO < 90000
# moving on
# 707
# 1413476 1413361 115
# abs FTO < 90000
# moving on
# 709
# 1416476 1413884 2592
# abs FTO < 90000
# moving on
# 710
# 1417212 1419168 -1956
# abs FTO < 90000
# moving on
# 712
# 1419781 1419168 613
# abs FTO < 90000
# moving on
# 713
# 1425988 1425769 219
# abs FTO < 90000
# moving on
# 715
# 1428310 1427497 813
# abs FTO < 90000
# moving on
# 717
# 1433023 1431088 1935
# abs FTO < 90000
# moving on
# 719
# 1435798 1435337 461
# abs FTO < 90000
# moving on
# 720
# 1440713 1440739 -26
# abs FTO < 90000
# moving on
# 721
# 1443988 1444270 -282
# abs FTO < 90000
# moving on
# 723
# 1454559 1454050 509
# abs FTO < 90000
# moving on
# 724
# 1455396 1455239 157
# abs FTO < 90000
# moving on
# 725
# 1460186 1460014 172
# abs FTO < 90000
# moving on
# 726
# 1460304 1460597 -293
# abs FTO < 90000
# moving on
# 729
# 1466177 1465171 1006
# abs FTO < 90000
# moving on
# 732
# 1467177 1466701 476
# abs FTO < 90000
# moving on
# 733
# FTO is greater than 90000
# 1467254 1466701 553
# abs FTO 2 is < 90000
# moving on
# 735
# 1470485 1470220 265
# abs FTO < 90000
# moving on
# 736
# 1470612 1470964 -352
# abs FTO < 90000
# moving on
# 738
# 1471295 1471458 -163
# abs FTO < 90000
# moving on
# 740
# 1472781 1473473 -692
# abs FTO < 90000
# moving on
# 741
# 1473810 1473955 -145
# abs FTO < 90000
# moving on
# 742
# 1480318 1480559 -241
# abs FTO < 90000
# moving on
# 743
# 1481088 1480841 247
# abs FTO < 90000
# moving on
# 745
# 1483089 1482822 267
# abs FTO < 90000
# moving on
# 746
# 1483467 1483485 -18
# abs FTO < 90000
# moving on
# 748
# 1485038 1483940 1098
# abs FTO < 90000
# moving on
# 750
# 1490059 1488961 1098
# abs FTO < 90000
# moving on
# 751
# 1493310 1493254 56
# abs FTO < 90000
# moving on
# 753
# 1497251 1496029 1222
# abs FTO < 90000
# moving on
# 754
# 1499624 1500145 -521
# abs FTO < 90000
# moving on
# 756
# 1509544 1508352 1192
# abs FTO < 90000
# moving on
# 758
# 1514471 1514041 430
# abs FTO < 90000
# moving on
# 759
# 1514571 1514920 -349
# abs FTO < 90000
# moving on
# 760
# 1525162 1525970 -808
# abs FTO < 90000
# moving on
# 761
# 1529971 1529790 181
# abs FTO < 90000
# moving on
# 763
# 1530677 1530371 306
# abs FTO < 90000
# moving on
# 764
# 1534970 1536090 -1120
# abs FTO < 90000
# moving on
# 766
# 1537142 1536090 1052
# abs FTO < 90000
# moving on
# 768
# 1539932 1539530 402
# abs FTO < 90000
# moving on
# 769
# 1545350 1545082 268
# abs FTO < 90000
# moving on
# 771
# 1549748 1549284 464
# abs FTO < 90000
# moving on
# 773
# 1551310 1550248 1062
# abs FTO < 90000
# moving on
# 774
# 1556872 1557574 -702
# abs FTO < 90000
# moving on
# 775
# 1558148 1558109 39
# abs FTO < 90000
# moving on
# 776
# 1560973 1561816 -843
# abs FTO < 90000
# moving on
# 778
# 1562352 1562011 341
# abs FTO < 90000
# moving on
# 779
# 1567251 1567060 191
# abs FTO < 90000
# moving on
# 780
# 1571290 1571461 -171
# abs FTO < 90000
# moving on
# 782
# 1572967 1572585 382
# abs FTO < 90000
# moving on
# 783
# 1573816 1574145 -329
# abs FTO < 90000
# moving on
# 784
# 1574426 1574503 -77
# abs FTO < 90000
# moving on
# 786
# 1580364 1579151 1213
# abs FTO < 90000
# moving on
# 787
# 1588644 1588585 59
# abs FTO < 90000
# moving on
# 789
# 1589869 1588972 897
# abs FTO < 90000
# moving on
# 790
# 1590316 1590263 53
# abs FTO < 90000
# moving on
# 791
# 1594668 1596186 -1518
# abs FTO < 90000
# moving on
# 793
# 1597319 1596186 1133
# abs FTO < 90000
# moving on
# 794
# 1603272 1603372 -100
# abs FTO < 90000
# moving on
# 795
# 1605837 1608140 -2303
# abs FTO < 90000
# moving on
# 796
# 1608177 1608140 37
# abs FTO < 90000
# moving on
# 797
# 1609730 1609491 239
# abs FTO < 90000
# moving on
# 799
# 1611958 1610970 988
# abs FTO < 90000
# moving on
# 800
# 1615171 1615192 -21
# abs FTO < 90000
# moving on
# 802
# 1619307 1618201 1106
# abs FTO < 90000
# moving on

# %% [markdown]
# # GOAL: to calculate the relevant FTOs / durations for analysis
# This includes:
# <b>FTOs</b>
# (1) trouble source FTO
# (2) OIR FTO
# (3) solution FTO
#
# <b>Durations</b>
# (4) trouble source duration
# (5) OIR duration
# (6) solution duration
#
# <b>speaker data</b>
# (7) trouble source speaker
# (8) OIR speaker
# (9) solution speaker
#
# <b>turns</b>
# (10) trouble source turn
# (11) OIR turn
# (12) solution turn
#
# <b>metadata</b>
# (13) file name
# (14) line number of trouble source
# (15)
#
# <b>other values</b>
# overlapping talk during the trouble source that doesn't come from the trouble source (can I even analyze this?)
# also, probability the OIR FTO comes from the general distribution of FTOs
#
# Note: someone will have to make sure the solution is a real solution!

# %%
#pip install pandas 
#pip install xlrd
import pandas as pd 
import xlrd

# %%
file = open("2018-11-06-session-1.cha")
lines = file.readlines()

# %%
print(lines[10])
# Out:
# 	(0.5) 217895_218426

# %%
data = pd.read_excel(file)

print(data)
# Out:
#      line previousturn_speaker  previousturn_starttime  previousturn_endtime  \
# 0      13                 *SP2                   52306                 53725
# 1      13                 *SP1                   53606                 54076
# 2      14                 *SP2                   61881                 65646
# 3      16                 *SP1                   65602                 65986
# 4      17                 *SP2                   67065                 68769
# 5      19                 *SP1                   67893                 69030
# 6      21                 *SP2                   73181                 80767
# 7      23                 *SP1                   82695                 89258
# 8      24                 *SP2                   89995                 94600
# 9      25                 *SP1                   94488                 95250
# 10     27                 *SP2                   95046                101895
# 11     29                 *SP1                  102962                103216
# 12     30                 *SP2                  103820                104779
# 13     31                 *SP1                  103918                105360
# 14     33                 *SP2                  105439                107000
# 15     34                 *SP1                  105541                108720
# 16     35                 *SP2                  108567                111334
# 17     36                 *SP1                  111111                111786
# 18     37                 *SP2                  111651                114595
# 19     38                 *SP1                  114297                114818
# 20     39                 *SP2                  115023                119939
# 21     40                 *SP1                  119590                120172
# 22     41                 *SP2                  120369                125683
# 23     42                 *SP2                  120369                125683
# 24     43                 *SP1                  125353                126532
# 25     44                 *SP2                  126279                126834
# 26     47                 *SP1                  130760                134846
# 27     48                 *SP2                  134976                135727
# 28     49                 *SP1                  135639                137997
# 29     51                 *SP2                  137458                138337
# ..    ...                  ...                     ...                   ...
# 420   751                 *SP2                 1490059               1493254
# 421   754                 *SP1                 1497251               1500145
# 422   758                 *SP2                 1509544               1514041
# 423   759                 *SP1                 1514471               1514920
# 424   760                 *SP2                 1514571               1525970
# 425   761                 *SP1                 1525162               1529790
# 426   763                 *SP2                 1529971               1530371
# 427   764                 *SP1                 1530677               1536090
# 428   768                 *SP1                 1537142               1539530
# 429   771                 *SP2                 1545350               1549284
# 430   773                 *SP1                 1549748               1550248
# 431   774                 *SP2                 1551310               1557574
# 432   775                 *SP1                 1556872               1558109
# 433   776                 *SP2                 1558148               1561816
# 434   778                 *SP1                 1560973               1562011
# 435   779                 *SP2                 1562352               1567060
# 436   780                 *SP1                 1567251               1571461
# 437   782                 *SP2                 1571290               1572585
# 438   783                 *SP1                 1572967               1574145
# 439   784                 *SP2                 1573816               1574503
# 440   787                 *SP1                 1580364               1588585
# 441   789                 *SP2                 1588644               1588972
# 442   790                 *SP1                 1589869               1590263
# 443   791                 *SP2                 1590316               1596186
# 444   794                 *SP2                 1597319               1603372
# 445   795                 *SP1                 1603272               1608140
# 446   796                 *SP1                 1603272               1608140
# 447   797                 *SP2                 1608177               1609491
# 448   799                 *SP1                 1609730               1610970
# 449   800                 *SP2                 1611958               1615192
#
#                                          previous_turn    FTO  \
# 0                            I feel like an actor now    -119
# 1                                                yeah    7805
# 2    This is like this room's like set up like I li...    -44
# 3                                                  ...   1079
# 4                  When will ‚åà CNN recognize ‚åâ me    -876
# 5                         ‚åä This is a news cast ‚åã    4151
# 6    If I like (0.2) <had to um> (0.7) I think like...   1928
# 7    I don't (1.0) I think like if I had (.) talent...    737
# 8    I feel like my ultimate life goal would be in ...   -112
# 9                                                  ...   -204
# 10   ‚åäL‚åãike I don't know I feel like (0.3) a li...   1067
# 11                                               Like     604
# 12                  Like ‚åàsomething like I could‚åâ    -861
# 13                      ‚åä Like ‚åã (.) job security      79
# 14                     Yeah ‚åà like job security ‚åâ   -1459
# 15        ‚åä like there's gonna be ‚åã (0.3) there...   -153
# 16   ‚åäI‚åã know also like cultural impact ‚åàtoo‚...   -223
# 17                                       ‚åä Yeah ‚åã    -135
# 18   like literally everyone knows who like Carrie ...   -298
# 19                                       ‚åä Yeah ‚åã     205
# 20   like (.) I don't know it's they're like really...   -349
# 21                                           ‚åämm‚åã     197
# 22   I feel like the only problems like people (.) ...  -1195
# 23   I feel like the only problems like people (.) ...   -330
# 24                    ‚åälike‚åã Harry ‚åà potter ‚åâ    -253
# 25                                      ‚åä  Yea‚åã‚åà   -158
# 26   And honestly like (0.7) I guess wait what's wh...    130
# 27                                Emma ‚åà Watson ‚åâ     -88
# 28         ‚åä Emma ‚åã Watson has done a better ‚å...   -539
# 29                                            ‚åä I...    802
# ..                                                 ...    ...
# 420        That are not like (0.5) common experiences      56
# 421  Like why would I watch movie that an average p...   -521
# 422  Uhm like about like (0.9) &=laughs because lik...    430
# 423                                               mhm    -349
# 424  I know like I don't I don't really like high s...   -808
# 425                                                ...    181
# 426                                               mhm     306
# 427  because what they do is like the take (.) kind...  -1120
# 428                 It's like (0.8) more rial I don't     402
# 429  If you like went to high school and like the e...    464
# 430                                              Yeah    1062
# 431  Because &=laughs the culture is like definitel...   -702
# 432                                                ...     39
# 433  He has not like we're going to like I don't kn...   -843
# 434                                                ...    341
# 435  Psych over gonna like say things about you and...    191
# 436  AC into all the (0.4) boys I've (0.5) loved th...   -171
# 437                                                ...    382
# 438                  Wait you haven't ‚åà seen it ‚åâ    -329
# 439                                      ‚åä  No‚åã‚åà    -77
# 440  Great (.) and also like (0.8) yeah I mean they...     59
# 441                                                NaN    897
# 442                                              Yeah      53
# 443  I think (0.4) the (.) main issues yes because ...  -1518
# 444  So like when you see a like (.) a high school ...   -100
# 445                                                ...  -2303
# 446                                                ...     37
# 447                                    I know exactly     239
# 448                                  Not at my school     988
# 449  Like it (0.6) my freshman look like literal ‚å...    -21
#
#                                              next_turn  nextturn_starttime  \
# 0                                                yeah                53606
# 1    This is like this room's like set up like I li...               61881
# 2                                                  ...               65602
# 3                  When will ‚åà CNN recognize ‚åâ me                67065
# 4                         ‚åä This is a news cast ‚åã                67893
# 5    If I like (0.2) <had to um> (0.7) I think like...               73181
# 6    I don't (1.0) I think like if I had (.) talent...               82695
# 7    I feel like my ultimate life goal would be in ...               89995
# 8                                                  ...               94488
# 9    ‚åäL‚åãike I don't know I feel like (0.3) a li...               95046
# 10                                               Like               102962
# 11                  Like ‚åàsomething like I could‚åâ               103820
# 12                      ‚åä Like ‚åã (.) job security               103918
# 13                     Yeah ‚åà like job security ‚åâ               105439
# 14        ‚åä like there's gonna be ‚åã (0.3) there...              105541
# 15   ‚åäI‚åã know also like cultural impact ‚åàtoo‚...              108567
# 16                                       ‚åä Yeah ‚åã               111111
# 17   like literally everyone knows who like Carrie ...              111651
# 18                                       ‚åä Yeah ‚åã               114297
# 19   like (.) I don't know it's they're like really...              115023
# 20                                           ‚åämm‚åã               119590
# 21   I feel like the only problems like people (.) ...              120369
# 22                                                 ...              124488
# 23                    ‚åälike‚åã Harry ‚åà potter ‚åâ               125353
# 24                                      ‚åä  Yea‚åã‚åà              126279
# 25                     ‚åä Like Daniel ‚åã Radcliff...              126676
# 26                                Emma ‚åà Watson ‚åâ               134976
# 27         ‚åä Emma ‚åã Watson has done a better ‚å...              135639
# 28                                            ‚åä I...              137458
# 29   But (.) I feel like Daniel Radcliffe just gave...              139139
# ..                                                 ...                 ...
# 420                          Oh (0.6) yeah (0.3) like              1493310
# 421                                                ...             1499624
# 422                                               mhm              1514471
# 423  I know like I don't I don't really like high s...             1514571
# 424                                                ...             1525162
# 425                                               mhm              1529971
# 426  because what they do is like the take (.) kind...             1530677
# 427                                                ...             1534970
# 428  But I guess like (0.3) those movies probably m...             1539932
# 429                                              Yeah              1549748
# 430  Because &=laughs the culture is like definitel...             1551310
# 431                                                ...             1556872
# 432  He has not like we're going to like I don't kn...             1558148
# 433                                                ...             1560973
# 434  Psych over gonna like say things about you and...             1562352
# 435  AC into all the (0.4) boys I've (0.5) loved th...             1567251
# 436                                                ...             1571290
# 437                  Wait you haven't ‚åà seen it ‚åâ              1572967
# 438                                      ‚åä  No‚åã‚åà             1573816
# 439                         ‚åä You ‚åã should defi...             1574426
# 440                                                NaN             1588644
# 441                                              Yeah              1589869
# 442  I think (0.4) the (.) main issues yes because ...             1590316
# 443                                                ...             1594668
# 444                                                ...             1603272
# 445                                                ...             1605837
# 446                                    I know exactly              1608177
# 447                                  Not at my school              1609730
# 448  Like it (0.6) my freshman look like literal ‚å...             1611958
# 449                                              ‚å...             1615171
#
#      nextturn_endtime nextturn_speaker OIR?
# 0               54076             *SP1  NaN
# 1               65646             *SP2  NaN
# 2               65986             *SP1  NaN
# 3               68769             *SP2  NaN
# 4               69030             *SP1  NaN
# 5               80767             *SP2  NaN
# 6               89258             *SP1  NaN
# 7               94600             *SP2  NaN
# 8               95250             *SP1  NaN
# 9              101895             *SP2  NaN
# 10             103216             *SP1  NaN
# 11             104779             *SP2  NaN
# 12             105360             *SP1  NaN
# 13             107000             *SP2  NaN
# 14             108720             *SP1  NaN
# 15             111334             *SP2  NaN
# 16             111786             *SP1  NaN
# 17             114595             *SP2  NaN
# 18             114818             *SP1  NaN
# 19             119939             *SP2  NaN
# 20             120172             *SP1  NaN
# 21             125683             *SP2  NaN
# 22             125000             *SP1  NaN
# 23             126532             *SP1  NaN
# 24             126834             *SP2  NaN
# 25             129760             *SP1  NaN
# 26             135727             *SP2  NaN
# 27             137997             *SP1  NaN
# 28             138337             *SP2  NaN
# 29             141516             *SP1  NaN
# ..                ...              ...  ...
# 420           1496029             *SP1  NaN
# 421           1508352             *SP2  NaN
# 422           1514920             *SP1  NaN
# 423           1525970             *SP2  NaN
# 424           1529790             *SP1  NaN
# 425           1530371             *SP2  NaN
# 426           1536090             *SP1  NaN
# 427           1535585             *SP2  NaN
# 428           1545082             *SP2  NaN
# 429           1550248             *SP1  NaN
# 430           1557574             *SP2  NaN
# 431           1558109             *SP1  NaN
# 432           1561816             *SP2  NaN
# 433           1562011             *SP1  NaN
# 434           1567060             *SP2  NaN
# 435           1571461             *SP1  NaN
# 436           1572585             *SP2  NaN
# 437           1574145             *SP1  NaN
# 438           1574503             *SP2  NaN
# 439           1579151             *SP1  NaN
# 440           1588972             *SP2  NaN
# 441           1590263             *SP1  NaN
# 442           1596186             *SP2  NaN
# 443           1595864             *SP1  NaN
# 444           1608140             *SP1  NaN
# 445           1606115             *SP2  NaN
# 446           1609491             *SP2  NaN
# 447           1610970             *SP1  NaN
# 448           1615192             *SP2  NaN
# 449           1618201             *SP1  NaN
#
# [450 rows x 11 columns]

# %%
is_OIR = data['OIR?']=="X"
OIRs = data[is_OIR]
nonOIRs = data[is_OIR== False]
nonOIR_FTOs = nonOIRs['FTO']

# %%
import matplotlib.pyplot as plt
plt.hist(nonOIR_FTOs.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-6d22f017c1ad> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.hist(nonOIR_FTOs.values)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6719                     # python's min/max ignore nan,
#    6720                     # np.minnan returns nan for all nan input
# -> 6721                     xmin = min(xmin, np.nanmin(xi))
#    6722                     xmax = max(xmax, np.nanmax(xi))
#    6723             # make sure we have seen at least one non-nan and finite
#
# //anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     296         # Slow, but safe for subclasses of ndarray
#     297         a, mask = _replace_nan(a, +np.inf)
# --> 298         res = np.amin(a, axis=axis, out=out, **kwargs)
#     299         if mask is None:
#     300             return res
#
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
nonOIR_FTOs.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-c2c2aa539eb1> in <module>
# ----> 1 nonOIR_FTOs.plot()
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
nonOIR_FTOs.values[:]
# Out:
# array([-119, 7805, -44, 1079, -876, 4151, 1928, 737, -112, -204, 1067,
#        604, -861, 79, -1459, -153, -223, -135, -298, 205, -349, 197,
#        -1195, -330, -253, -158, 130, -88, -539, 802, 216, -56, -687, 277,
#        207, 93, -832, -233, 360, -223, -547, -114, 1279, 417, -1179, 1597,
#        -89, 51, -244, -244, 88, -18, -112, -228, 730, 784, 323, 660, 78,
#        -360, 175, -415, -272, 33, '‚åâ ', '‚åâ ', 282, -6, -16, ' ', 88,
#        105, 1268, 205, 35, -200, 1772, -112, 1609, 398, -512, -3526, 56,
#        -29, 329, -448, 151, -386, 235, -407, -211, 237, 70, 159, 1167,
#        -441, 1144, -441, -384, 602, -368, 774, 1070, -175, -220, 381,
#        -1426, 282, 184, -1098, 262, -381, 128, 181, -42, 286, -314, 1490,
#        686, 291, -3589, 97, -102, 40, 21, 523, -32, 86, -2119, -214, 581,
#        551, 1796, 1257, -6, 158, -621, -400, -798, -1369, 2287, 300, -175,
#        -25, -252, 212, 507, 591, -477, 827, 1067, -569, 437, -250, -20,
#        114, -156, 1123, -1039, -25, -342, 889, 33, -1789, 923, -681, 484,
#        -500, 782, -179, 1460, 1723, 456, 310, 14, -485, 467, -745, 53,
#        -1277, 193, 1072, 365, -269, 46, 51, 670, 56, 1397, 516, 357, 668,
#        -160, -9, -433, 942, -1309, 942, -709, 21, -37, 100, 840, 123,
#        -124, -135, -92, 1112, 5, -875, 1370, 642, 1479, -1462, -21, -758,
#        -215, 317, -400, -217, 772, -260, -65, 1700, 305, 558, -2398, 377,
#        1578, -896, -860, 253, -648, -503, -2227, -21, 829, -257, -303,
#        294, -180, 142, -278, 570, 60, -162, -230, -644, -684, 35, 560,
#        960, -98, -181, 263, -347, 345, 242, -127, -14, 244, 85, -28, 119,
#        -69, -1225, -315, 1613, 1120, 953, -98, -40, -267, 35, 380, 607,
#        -724, 978, 52, 500, 875, -95, 288, 618, 318, -1239, 147, 610, 917,
#        -210, -3485, 350, 1240, -230, -1824, -2253, 171, -361, -3, 998,
#        -1210, 1038, -1343, 414, -270, -98, 100, 3320, -100, ' ‚åâ ', 204,
#        '‚åâ ', -237, -163, ' yÃ≤', -1163, 115, ' ', -188, 205, -352, 122,
#        1603, 15, 1547, 76, -3, 177, 46, 363, -621, 840, 389, -168, 3,
#        -393, 675, -293, -16, -164, 731, -3, 343, -447, 311, -98, 781, 181,
#        -1457, 2, 9, -2402, -905, 542, 455, -44, 196, -3658, 278, 1763,
#        -62, -420, -183, 127, -642, 36, 27, -829, -242, 165, -157, -118,
#        -546, 169, 991, 1047, -675, 47, 304, -301, -62, -12, 1793, -319,
#        -506, 852, -111, -15, 775, 598, 902, 349, 5, 1003, 115, -1956, 613,
#        219, 813, 1935, 461, -26, -282, 509, 157, 172, -293, 1006, 476,
#        -352, -163, -692, -145, -241, 247, 267, -18, 56, -521, 430, -349,
#        -808, 181, 306, -1120, 402, 464, 1062, -702, 39, -843, 341, 191,
#        -171, 382, -329, -77, 59, 897, 53, -1518, -100, -2303, 37, 239,
#        988, -21], dtype=object)

# %%
hmm["FTO"]
# Out:
# 1    7805
# Name: FTO, dtype: object

# %%
# if the "OIR?" file is "X", then do the following 

# get the FTO of that row (the OIR FTO)

# get the FTO of the previous row (the trouble source FTO)

# get the FTO of the next row (the solution FTOd)

# %%
import os
import glob

writefile = open("trythis.txt", "a")

for filename in glob.glob('*.cha'):
    with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
        for line in f: 
            if line[0] == "*": 
                writefile.write(line)
                
        writefile.write("<|endoftext|>\n")

writefile.close()

# %%
os.getcwd()
# Out:
# '/Users/julia/Desktop'
